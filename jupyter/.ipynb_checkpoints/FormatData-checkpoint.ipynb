# %%
import pandas as pd
import zipfile
import os
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pickle
import cv2
import urllib

# %% [markdown]
# ### Set filepath for unzipped data

# %%
FILEPATH = "data/unzipped/train/"

# %% [markdown]
# ### Create a dataframe with the name and label of each entry in the unzipped entries

# %%
train_set = pd.DataFrame({"image": os.listdir("data/unzipped/train")})
train_set["label"] = train_set["image"].apply(lambda x: x.split(".")[0])#.replace({'dog': 1, 'cat':0})

train_set = train_set.sample(frac=1)

train_set.reset_index(drop=True, inplace=True)

train_set
# Out:
#               image label
# 0      cat.9471.jpg   cat
# 1      cat.9674.jpg   cat
# 2      dog.5630.jpg   dog
# 3      dog.6793.jpg   dog
# 4      cat.9266.jpg   cat
# ...             ...   ...
# 24995  dog.8752.jpg   dog
# 24996  cat.6679.jpg   cat
# 24997  dog.2414.jpg   dog
# 24998  dog.5005.jpg   dog
# 24999  dog.5212.jpg   dog
#
# [25000 rows x 2 columns]

# %% [markdown]
# ### Visualize the class imbalance if any

# %%
fig, ax = plt.subplots(figsize = (8, 8))

sns.countplot(x = "label", palette="Set1", data = train_set, ax = ax)

ax.set_title("Distribution of Class Labels")
sns.despine()
plt.show()

# %% [markdown]
# ### Create our training data

# %%
training_data = []

for index, row in train_set.iterrows():
    image = row['image']
    label = row['label']
    filepath = FILEPATH + "/" + image
    image_array = cv2.imread(filepath)
    image_array = cv2.imread(filepath, cv2.IMREAD_GRAYSALE)
    image_array = cv2.resize(image_array, (100,100))
    training_data.append([image, image_array, label])

# %% [markdown]
# ### Split training data into X and y

# %%
images = []
X = []
y = []

for image, feature, label in training_data:
    images.append(image)
    X.append(feature)
    y.append(label)

# %%
X = np.array(X)

# %%
X.shape
# Out:
# (25000, 100, 100, 3)

# %% [markdown]
# ### Reshape X for use in Conv2D

# %%
X = np.array(X).reshape(-1,100,100,3)

# %%
X.shape
# Out:
# (25000, 100, 100, 3)

# %%
pickle_out = open("X.pickle","wb")
pickle.dump(X, pickle_out)
pickle_out.close()

pickle_out = open("y.pickle","wb")
pickle.dump(y, pickle_out)
pickle_out.close()

pickle_out = open("images.pickle","wb")
pickle.dump(images, pickle_out)
pickle_out.close()

# %% [markdown]
# ## Read image from url

# %%
model = pickle.l

# %%
url = "https://i.guim.co.uk/img/media/26392d05302e02f7bf4eb143bb84c8097d09144b/446_167_3683_2210/master/3683.jpg?width=1200&height=1200&quality=85&auto=format&fit=crop&s=49ed3252c0b2ffb49cf8b508892e452d"
req = urllib.request.urlopen(url)
arr = np.asarray(bytearray(req.read()), dtype=np.uint8)
img = cv2.imdecode(arr, flags=1) # 'Load it as it is'
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img = cv2.resize(img, (400,400))

plt.imshow(img)

# %%
img
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)
